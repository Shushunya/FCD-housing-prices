# %% [markdown]
# # Engineering weather-based features and age buckets

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline


import pandas as pd
import warnings
from src.config import (WEATHER_FILE, WEATHER_QUARTER_FILE,)
from src.config import AGE_CLEAN_FILE, MASTER_DF_FILE, AGE_BUCKET_FILE


warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Weather features

# %%
weather_daily_df = pd.read_csv(WEATHER_FILE, index_col=0)
weather_daily_df.head()
# Out:
#               region        date  temp_max_c  temp_min_c  sunshine_duration_s  \
# 0  Arcos de Valdevez  2019-01-01        16.4         6.9             29242.46
# 1  Arcos de Valdevez  2019-01-02        14.6         4.5             29295.18
# 2  Arcos de Valdevez  2019-01-03        13.9         8.5             29352.68
# 3  Arcos de Valdevez  2019-01-04        14.5         7.2             29414.80
# 4  Arcos de Valdevez  2019-01-05        14.8         6.7             29481.41
#
#    windspeed_mean_kmh  precipitation_sum_mm
# 0                 4.5                   0.0
# 1                 5.0                   0.0
# 2                 2.8                   0.0
# 3                 3.0                   0.0
# 4                 4.4                   0.0

# %% [markdown]
# The data is daily and all of the other data we operate is either yearly, or quarterly. The first step is to add the quarter column and unify the municipality column name.

# %%
weather_daily_df["date"] = pd.to_datetime(weather_daily_df["date"])
weather_daily_df = weather_daily_df[weather_daily_df["date"] >= "2019-10-01"]
weather_daily_df["quarter_year"] = weather_daily_df["date"].dt.to_period("Q").astype(str).str.replace(r'(\d{4})Q(\d)', r"\2Q \1", regex=True)
weather_daily_df = weather_daily_df.rename(columns={'region': 'municipality'})

# %% [markdown]
# Convert the sunshine duration from seconds to hours, so it's more interpretable and human readable.

# %%
weather_daily_df["sunshine_duration_h"] = weather_daily_df["sunshine_duration_s"] / 3600
weather_daily_df = weather_daily_df.drop(columns=["sunshine_duration_s"])

# %% [markdown]
# Add the comfort helper columns that will help calculated the desired comfort metrics (amount of rainy/sunny/etc days per municipality per quarter).

# %%
# Helper columns
weather_daily_df["is_rainy"] = weather_daily_df["precipitation_sum_mm"] > 0
weather_daily_df["is_sunny"] = weather_daily_df["sunshine_duration_h"] >= 8
weather_daily_df["is_windy"] = weather_daily_df["windspeed_mean_kmh"] > 30.0
weather_daily_df["no_rain"] = weather_daily_df["precipitation_sum_mm"] == 0
weather_daily_df["is_temp_ok"] = (weather_daily_df["temp_min_c"] >= 17) & (weather_daily_df["temp_max_c"] <= 28)
weather_daily_df["temp_mean_c"] = (weather_daily_df["temp_max_c"] + weather_daily_df["temp_min_c"]) / 2

# %% [markdown]
# Group and aggregate everything and save the file.

# %%
weather_quarter_df = weather_daily_df.groupby(by=["municipality", "quarter_year"]).agg(
    # aggregate for the quarter values
    total_sunshine_h=pd.NamedAgg(column="sunshine_duration_h", aggfunc="sum"),
    mean_sunshine_h=pd.NamedAgg(column="sunshine_duration_h", aggfunc="mean"),
    windspeed_mean_kmh=pd.NamedAgg(column="windspeed_mean_kmh", aggfunc="mean"),
    total_precipitation_mm=pd.NamedAgg(column="precipitation_sum_mm", aggfunc="sum"),
    mean_precipitation_mm=pd.NamedAgg(column="precipitation_sum_mm", aggfunc="mean"),

    # features
    windy_days=pd.NamedAgg(column="is_windy", aggfunc="sum"),
    rainy_days=pd.NamedAgg(column="is_rainy", aggfunc="sum"),
    sunny_days=pd.NamedAgg(column="is_sunny", aggfunc="sum"),
    warm_days=pd.NamedAgg(column="is_temp_ok", aggfunc="sum")
).reset_index()
weather_quarter_df[weather_quarter_df["municipality"] == "Aveiro"]
# Out:
#     municipality quarter_year  total_sunshine_h  mean_sunshine_h  \
# 814       Aveiro      1Q 2020        694.762311         7.634751
# 815       Aveiro      1Q 2021        678.421267         7.538014
# 816       Aveiro      1Q 2022        720.760794         8.008453
# 817       Aveiro      1Q 2023        725.641950         8.062688
# 818       Aveiro      1Q 2024        649.753275         7.140146
# 819       Aveiro      1Q 2025        628.320958         6.981344
# 820       Aveiro      2Q 2020       1032.213533        11.343006
# 821       Aveiro      2Q 2021       1058.906956        11.636340
# 822       Aveiro      2Q 2022       1056.350025        11.608242
# 823       Aveiro      2Q 2023       1059.420886        11.641988
# 824       Aveiro      2Q 2024       1037.488208        11.400969
# 825       Aveiro      3Q 2020       1096.805706        11.921801
# 826       Aveiro      3Q 2021       1047.430133        11.385110
# 827       Aveiro      3Q 2022       1078.582922        11.723727
# 828       Aveiro      3Q 2023       1070.145944        11.632021
# 829       Aveiro      3Q 2024       1050.284869        11.416140
# 830       Aveiro      4Q 2019        586.857447         6.378885
# 831       Aveiro      4Q 2020        640.479322         6.961732
# 832       Aveiro      4Q 2021        687.837383         7.476493
# 833       Aveiro      4Q 2022        536.212681         5.828399
# 834       Aveiro      4Q 2023        581.979242         6.325861
# 835       Aveiro      4Q 2024        653.917503         7.107799
#
#      windspeed_mean_kmh  total_precipitation_mm  mean_precipitation_mm  \
# 814           12.800000                   234.2               2.573626
# 815           13.444444                   342.1               3.801111
# 816           11.788889                   170.5               1.894444
# 817           12.898889                   273.0               3.033333
# 818           14.617582                   591.3               6.497802
# 819           13.076667                   674.8               7.497778
# 820           13.409890                   258.4               2.839560
# 821           13.431868                   204.6               2.248352
# 822           14.840659                   204.8               2.250549
# 823           13.843956                   193.0               2.120879
# 824           14.370330                   256.6               2.819780
# 825           14.063043                    51.2               0.556522
# 826           13.777174                   113.2               1.230435
# 827           13.186957                   146.6               1.593478
# 828           14.493478                   135.5               1.472826
# 829           14.704348                    94.1               1.022826
# 830           15.431522                   637.8               6.932609
# 831           13.556522                   410.8               4.465217
# 832           12.431522                   321.7               3.496739
# 833           14.363043                   818.7               8.898913
# 834           13.255435                   575.2               6.252174
# 835           11.765217                   331.1               3.598913
#
#      windy_days  rainy_days  sunny_days  warm_days
# 814           0          46          60          0
# 815           2          45          56          0
# 816           0          28          67          0
# 817           2          42          66          0
# 818           4          54          48          0
# 819           2          59          46          0
# 820           0          49          79          5
# 821           0          45          80          2
# 822           2          47          81          7
# 823           3          39          85         12
# 824           0          43          82          4
# 825           0          19          89         17
# 826           0          27          86         11
# 827           0          22          86         25
# 828           0          28          87         36
# 829           0          20          85         25
# 830           5          62          46          4
# 831           1          56          48          0
# 832           0          41          60          2
# 833           0          66          32          3
# 834           3          56          48          7
# 835           1          51          55          8

# %%
weather_quarter_df.to_csv(WEATHER_QUARTER_FILE, index=False)

# %% [markdown]
# ## Age buckets

# %%
age_df = pd.read_csv(AGE_CLEAN_FILE)
age_df
# Out:
#      municipality  year  10 - 14  15 - 19  20 - 24  25 - 29  30 - 34  35 - 39  \
# 0        Abrantes  2019   1529.0   1667.0   1512.0   1286.0   1338.0   1792.0
# 1        Abrantes  2020   1453.0   1623.0   1609.0   1266.0   1345.0   1686.0
# 2        Abrantes  2021   1388.0   1603.0   1628.0   1289.0   1328.0   1620.0
# 3        Abrantes  2022   1308.0   1606.0   1618.0   1348.0   1259.0   1623.0
# 4        Abrantes  2023   1250.0   1608.0   1659.0   1408.0   1362.0   1522.0
# ...           ...   ...      ...      ...      ...      ...      ...      ...
# 1535       Óbidos  2019    512.0    590.0    560.0    458.0    550.0    654.0
# 1536       Óbidos  2020    539.0    580.0    586.0    515.0    541.0    694.0
# 1537       Óbidos  2021    551.0    576.0    656.0    578.0    555.0    719.0
# 1538       Óbidos  2022    589.0    575.0    666.0    665.0    606.0    722.0
# 1539       Óbidos  2023    582.0    611.0    696.0    725.0    674.0    775.0
#
#       40 - 44  45 - 49   5 - 9  50 - 54  55 - 59  60 - 64  65 - 69  70 - 74  \
# 0      2382.0   2420.0  1165.0   2567.0   2796.0   2726.0   2590.0   2355.0
# 1      2215.0   2465.0  1135.0   2493.0   2744.0   2772.0   2666.0   2336.0
# 2      2042.0   2491.0  1113.0   2458.0   2686.0   2788.0   2713.0   2329.0
# 3      1954.0   2445.0  1102.0   2490.0   2621.0   2768.0   2670.0   2416.0
# 4      1876.0   2454.0  1133.0   2438.0   2600.0   2760.0   2706.0   2425.0
# ...       ...      ...     ...      ...      ...      ...      ...      ...
# 1535    814.0    892.0   499.0    846.0    922.0    870.0    866.0    765.0
# 1536    834.0    893.0   509.0    915.0    879.0    889.0    891.0    807.0
# 1537    842.0    919.0   508.0    917.0    896.0    928.0    890.0    845.0
# 1538    851.0    937.0   503.0    968.0    904.0    944.0    890.0    868.0
# 1539    861.0    978.0   540.0    966.0    920.0    976.0    926.0    887.0
#
#       75 - 79  80 - 84  85 ou mais  Menos de 5
# 0      1875.0   1833.0      2020.0      1078.0
# 1      1943.0   1737.0      2004.0      1066.0
# 2      1988.0   1670.0      2022.0      1016.0
# 3      2018.0   1593.0      2004.0      1015.0
# 4      2087.0   1553.0      1967.0      1003.0
# ...       ...      ...         ...         ...
# 1535    575.0    461.0       429.0       449.0
# 1536    612.0    491.0       415.0       447.0
# 1537    635.0    504.0       417.0       474.0
# 1538    674.0    496.0       447.0       522.0
# 1539    709.0    500.0       458.0       510.0
#
# [1540 rows x 20 columns]

# %% [markdown]
# All of the age ranges may be groupped based on the life stages (mentioned and explained in `02_eda_add.ipynb`)

# %%
age_cols = [col for col in age_df.columns if any(char.isdigit() for char in col) and '-' in col]

age_bucket_mapping = {
    "< 5": ["Menos de 5"],
    "5 - 19": ["5 - 9", "10 - 14", "15 - 19"],
    "20 - 34": ["20 - 24", "25 - 29", "30 - 34"],
    "35 - 54": ["35 - 39", "40 - 44", "45 - 49", "50 - 54"],
    "55 - 64": ["55 - 59", "60 - 64"],
    "> 65": ["65 - 69", "70 - 74", "75 - 79", "80 - 84", "85 ou mais"]
}

for new_bucket, old_buckets in age_bucket_mapping.items():
    matching_cols = [col for col in old_buckets if col in age_df.columns]
    if matching_cols:
        age_df[new_bucket] = age_df[matching_cols].sum(axis=1)

cols_to_drop = ["85 ou mais", "Menos de 5"] + [col for col in age_cols if col in age_df.columns]
age_df = age_df.drop(columns=cols_to_drop)
age_df
# Out:
#      municipality  year     < 5  5 - 19  20 - 34  35 - 54  55 - 64     > 65
# 0        Abrantes  2019  1078.0  4361.0   4136.0   9161.0   5522.0  10673.0
# 1        Abrantes  2020  1066.0  4211.0   4220.0   8859.0   5516.0  10686.0
# 2        Abrantes  2021  1016.0  4104.0   4245.0   8611.0   5474.0  10722.0
# 3        Abrantes  2022  1015.0  4016.0   4225.0   8512.0   5389.0  10701.0
# 4        Abrantes  2023  1003.0  3991.0   4429.0   8290.0   5360.0  10738.0
# ...           ...   ...     ...     ...      ...      ...      ...      ...
# 1535       Óbidos  2019   449.0  1601.0   1568.0   3206.0   1792.0   3096.0
# 1536       Óbidos  2020   447.0  1628.0   1642.0   3336.0   1768.0   3216.0
# 1537       Óbidos  2021   474.0  1635.0   1789.0   3397.0   1824.0   3291.0
# 1538       Óbidos  2022   522.0  1667.0   1937.0   3478.0   1848.0   3375.0
# 1539       Óbidos  2023   510.0  1733.0   2095.0   3580.0   1896.0   3480.0
#
# [1540 rows x 8 columns]

# %%
age_df.to_csv(AGE_BUCKET_FILE, index=False)
